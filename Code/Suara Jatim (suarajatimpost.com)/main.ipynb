# %% [markdown]
# ### Libraries

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import pandas as pd
from time import sleep
from random import randint

# %% [markdown]
# ### Main Function

# %%
def get_news(num_pages = 1,     
             num_articles = -1,  
             get_title = True,  
             get_url = True,    
             get_thumbnail = False,     
             get_content = False,       
             get_author = False,         
             get_publish_date = False,  
             news_type = 'newest',      
             set_sleep = 1,             
             debug = True               
):
    """ 
    Arguments description:
    - num_pages
        Number of pages to be collected, each pages may contain many articles
        Must be positive integer
    - num_articles
        Number of articles to be collected from all pages, may not be reached due to insufficient pages
        Must be positive integer, or -1 to collect all articles from all pages
    - get_title
        Get article title? 
        Must be boolean
    - get_url
        Get article URL?
        Must be boolean
    - get_thumbnail
        Get article thumbnail URL?
        Must be boolean
    - get_content
        Get article content? (collect all texts shown in the article)  
        Must be boolean
    - get_author
        Get article author
        Must be boolean
    - get_publish_date
        Get article publish date
        Must be boolean
    - news_type
        Article types
        Can be newest, peristiwa, pemerintahan, politik, hukum-kriminal, olahraga, ekonomi, lifestyle
    - set_sleep
        Set an interval between requests, recommended to keep it as is
        Must be non negative integer
    - debug
        Print debugging text, useful to know which elements are not accesible
        Must be boolean
        Currently not being used
    """
    
    # Argument Check
    # used to check whether argument values are expected
    if (type(num_pages) != int) or (num_pages < 1):
        print('argument num_pages must be positive integer!')
        return
    if (type(get_title) != bool or type(get_url) != bool or type(get_thumbnail) != bool or type(get_content) != bool):
        print('argument get_ must be boolean!')
        return
    if (type(set_sleep) != int or set_sleep < 0):
        print('argument set_sleep must be non-negative integer!')
        return
    allowable_news_type = ['newest', 'peristiwa', 'pemerintahan', 'politik', 'hukum-kriminal', 'olahraga', 'ekonomi', 'lifestyle']
    if news_type not in allowable_news_type:
        print('argument news_type must be one of the following:', allowable_news_type)

    # Adjust news_type url
    main_url = 'https://suarajatimpost.com/indeks'
    if news_type != 'newest':
        main_url = 'https://suarajatimpost.com/'+news_type

    # Prepare lists to contain each elements
    list_news = []
    list_article_title = []
    list_article_url = []
    list_article_thumbnail = []
    list_article_content = []
    list_article_author = []
    list_article_publish_date = []
    result = {}
    article_count = 0

    # Loop through pages, collect articles. Each articles is stored in 'list_news'.
    for i in range(num_pages):
        current_url = main_url+'?page='+str(i)
        print('Accessing page', i, ' - ', current_url)
        try:
            soup = bs(req.get(current_url).text, features='html.parser')
            list_news = list_news + soup.find("div", class_ = "col-sm-12 col-md-12 col-lg-8").findAll("div", class_ = "col-sm-12 col-md-6")
        except:
            print('Warning: error in page', i)
            break
        
        # Add a random sleep to not spam the website.
        if i>1:
            sleep(randint(set_sleep,set_sleep+1))

        # Check if num_articles is reached
        if num_articles != -1:
            article_count += len(list_news)
            if article_count > num_articles:
                print('num_articles reached!')
                list_news = list_news[0:num_articles]
                break    
    print('num_pages reached!')

    # Loop through articles, collect title, url, etc. Each elements is stored in corresponding list.
    for news in list_news:
        if get_title:
            title = news.find("h3", class_ = "title").text
            list_article_title.append(title)
        if get_url:
            url = news.find("h3", class_ = "title").find("a", href = True)['href']
            list_article_url.append(url)
        if get_thumbnail:
            thumbnail = news.find("img", class_ = "img-fluid lazyload")['data-src']
            list_article_thumbnail.append(thumbnail)
        if get_content or get_author or get_publish_date: 
            print('Accessing article -', url)
            article_soup = bs(req.get(url).text, features='html.parser')
            sleep(randint(set_sleep, set_sleep+1))
            if get_content:
                try:
                    list_article_content.append(article_soup.find('div', class_ = 'post-text mt-4').text.strip())
                except:
                    list_article_content.append("")
            if get_author:
                try:
                    list_article_author.append(article_soup.find(class_ = 'item-meta item-meta-author').text.strip())
                except:
                    list_article_author.append("")
            if get_publish_date:
                try:
                    list_article_publish_date.append(article_soup.find(class_ = "item-meta item-meta-date").text.strip())
                except:
                    list_article_publish_date.append("")
    print('Done!')

    # Store the result as a dataframe
    if get_title:           result['title'] = list_article_title
    if get_url:             result['url'] = list_article_url
    if get_thumbnail:       result['thumbnail'] = list_article_thumbnail
    if get_content:         result['content'] = list_article_content
    if get_author:          result['author'] = list_article_author
    if get_publish_date:    result['publish_date'] = list_article_publish_date
    df = pd.DataFrame(result)
    return(df)

# %% [markdown]
# ### Usage

# %%
get_news(num_pages = 2, get_thumbnail=True, get_content=True, get_author=True, get_publish_date=True, news_type='ekonomi')
# Out:
# Accessing page 0  -  https://suarajatimpost.com/ekonomi?page=0
# Accessing page 1  -  https://suarajatimpost.com/ekonomi?page=1
# num_pages reached!
# Accessing article - https://suarajatimpost.com/mahasiswa-unibo-dan-5-anggota-dprd-bondowoso-diskusi-isu-kemiskinan
# Accessing article - https://suarajatimpost.com/pabrik-rokok-terancam-gulung-tikar-jika-rpp-kesehatan-disahkan
# Accessing article - https://suarajatimpost.com/gelar-festival-buah-untuk-pengembangan-klaster-agribisnis-lamongan
# Accessing article - https://suarajatimpost.com/redam-inflasi-dan-stabilkan-harga-pemkot-probolinggo-gelar-gpm
# Accessing article - https://suarajatimpost.com/bangkitkan-semangat-anak-muda-berusaha-iibf-adakan-kopdar
# Accessing article - https://suarajatimpost.com/wilayah-3t-di-jatim-dapat-layanan-tukar-uang-hingga-rp-77-miliar-dalam-misi-erb
# Accessing article - https://suarajatimpost.com/rpp-turunan-uu-kesehatan-daniel-rohi-mengancam-petani-dan-industri-hasil-tembakau
# Accessing article - https://suarajatimpost.com/bale-branti-bumdes-yang-mampu-meraup-omset-hingga-rp-500-juta-sebulan
# Accessing article - https://suarajatimpost.com/harga-cabai-gula-merangkak-naik-bagaimana-dengan-harga-bahan-pokok-lain
# Accessing article - https://suarajatimpost.com/tekanan-inflasi-kota-malang-di-bulan-september-2023-tetap-terkendali
# Accessing article - https://suarajatimpost.com/produk-umkm-berbagai-daerah-peserta-mtq-ke-xxx-dipamerkan
# Accessing article - https://suarajatimpost.com/dua-poktan-tak-dapat-dbhcht-koordinator-ppl-kecamatan-kemlagi-angkat-bicara
# Accessing article - https://suarajatimpost.com/ojk-kediri-sambangi-pt-dan-liris-solo-ada-apa-ya
# Accessing article - https://suarajatimpost.com/tak-dapat-dbhct-dua-kelompok-tani-tembakau-di-kemlagi-mojokerto-gigit-jari
# Accessing article - https://suarajatimpost.com/usaha-es-krim-bisnis-kuliner-yang-cukup-menjanjikan-di-jombang
# Accessing article - https://suarajatimpost.com/bi-malang-kondisi-ekonomi-berada-di-level-optimis
# Accessing article - https://suarajatimpost.com/mahasiswa-unibo-dan-5-anggota-dprd-bondowoso-diskusi-isu-kemiskinan
# Accessing article - https://suarajatimpost.com/pabrik-rokok-terancam-gulung-tikar-jika-rpp-kesehatan-disahkan
# Accessing article - https://suarajatimpost.com/gelar-festival-buah-untuk-pengembangan-klaster-agribisnis-lamongan
# Accessing article - https://suarajatimpost.com/redam-inflasi-dan-stabilkan-harga-pemkot-probolinggo-gelar-gpm
# Accessing article - https://suarajatimpost.com/bangkitkan-semangat-anak-muda-berusaha-iibf-adakan-kopdar
# Accessing article - https://suarajatimpost.com/wilayah-3t-di-jatim-dapat-layanan-tukar-uang-hingga-rp-77-miliar-dalam-misi-erb
# Accessing article - https://suarajatimpost.com/rpp-turunan-uu-kesehatan-daniel-rohi-mengancam-petani-dan-industri-hasil-tembakau
# Accessing article - https://suarajatimpost.com/bale-branti-bumdes-yang-mampu-meraup-omset-hingga-rp-500-juta-sebulan
# Accessing article - https://suarajatimpost.com/harga-cabai-gula-merangkak-naik-bagaimana-dengan-harga-bahan-pokok-lain
# Accessing article - https://suarajatimpost.com/tekanan-inflasi-kota-malang-di-bulan-september-2023-tetap-terkendali
# Accessing article - https://suarajatimpost.com/produk-umkm-berbagai-daerah-peserta-mtq-ke-xxx-dipamerkan
# Accessing article - https://suarajatimpost.com/dua-poktan-tak-dapat-dbhcht-koordinator-ppl-kecamatan-kemlagi-angkat-bicara
# Accessing article - https://suarajatimpost.com/ojk-kediri-sambangi-pt-dan-liris-solo-ada-apa-ya
# Accessing article - https://suarajatimpost.com/tak-dapat-dbhct-dua-kelompok-tani-tembakau-di-kemlagi-mojokerto-gigit-jari
# Accessing article - https://suarajatimpost.com/usaha-es-krim-bisnis-kuliner-yang-cukup-menjanjikan-di-jombang
# Accessing article - https://suarajatimpost.com/bi-malang-kondisi-ekonomi-berada-di-level-optimis
# Done!
#                                                 title  \
# 0   Mahasiswa Unibo dan 5 Anggota DPRD Bondowoso D...
# 1   Pabrik Rokok Terancam Gulung Tikar, Jika RPP K...
# 2   Gelar Festival Buah untuk Pengembangan Klaster...
# 3   Redam Inflasi dan Stabilkan Harga, Pemkot Prob...
# 4   Bangkitkan Semangat Anak Muda Berusaha IIBF Ad...
# 5   Wilayah 3T di Jatim Dapat Layanan Tukar Uang H...
# 6   RPP Turunan UU Kesehatan, Daniel Rohi : Mengan...
# 7   Bale Branti, Bumdes Dengan Omset Rp 500 Juta S...
# 8   Harga Cabai, Gula merangkak Naik, Bagaimana de...
# 9   Tekanan Inflasi Kota Malang di Bulan September...
# 10  Produk UMKM Berbagai Daerah Peserta MTQ Ke XXX...
# 11  Dua Poktan Tak Dapat DBHCHT, Koordinator PPL K...
# 12  OJK Kediri Sambangi PT. Dan Liris Solo, Ada Ap...
# 13  Tak dapat DBHCT, Dua Kelompok Tani Tembakau di...
# 14  Usaha Es Krim, Bisnis Kuliner Yang Cukup Menja...
# 15  BI Malang : Kondisi Ekonomi Berada di Level Op...
# 16  Mahasiswa Unibo dan 5 Anggota DPRD Bondowoso D...
# 17  Pabrik Rokok Terancam Gulung Tikar, Jika RPP K...
# 18  Gelar Festival Buah untuk Pengembangan Klaster...
# 19  Redam Inflasi dan Stabilkan Harga, Pemkot Prob...
# 20  Bangkitkan Semangat Anak Muda Berusaha IIBF Ad...
# 21  Wilayah 3T di Jatim Dapat Layanan Tukar Uang H...
# 22  RPP Turunan UU Kesehatan, Daniel Rohi : Mengan...
# 23  Bale Branti, Bumdes Dengan Omset Rp 500 Juta S...
# 24  Harga Cabai, Gula merangkak Naik, Bagaimana de...
# 25  Tekanan Inflasi Kota Malang di Bulan September...
# 26  Produk UMKM Berbagai Daerah Peserta MTQ Ke XXX...
# 27  Dua Poktan Tak Dapat DBHCHT, Koordinator PPL K...
# 28  OJK Kediri Sambangi PT. Dan Liris Solo, Ada Ap...
# 29  Tak dapat DBHCT, Dua Kelompok Tani Tembakau di...
# 30  Usaha Es Krim, Bisnis Kuliner Yang Cukup Menja...
# 31  BI Malang : Kondisi Ekonomi Berada di Level Op...
#
#                                                   url  \
# 0   https://suarajatimpost.com/mahasiswa-unibo-dan...
# 1   https://suarajatimpost.com/pabrik-rokok-teranc...
# 2   https://suarajatimpost.com/gelar-festival-buah...
# 3   https://suarajatimpost.com/redam-inflasi-dan-s...
# 4   https://suarajatimpost.com/bangkitkan-semangat...
# 5   https://suarajatimpost.com/wilayah-3t-di-jatim...
# 6   https://suarajatimpost.com/rpp-turunan-uu-kese...
# 7   https://suarajatimpost.com/bale-branti-bumdes-...
# 8   https://suarajatimpost.com/harga-cabai-gula-me...
# 9   https://suarajatimpost.com/tekanan-inflasi-kot...
# 10  https://suarajatimpost.com/produk-umkm-berbaga...
# 11  https://suarajatimpost.com/dua-poktan-tak-dapa...
# 12  https://suarajatimpost.com/ojk-kediri-sambangi...
# 13  https://suarajatimpost.com/tak-dapat-dbhct-dua...
# 14  https://suarajatimpost.com/usaha-es-krim-bisni...
# 15  https://suarajatimpost.com/bi-malang-kondisi-e...
# 16  https://suarajatimpost.com/mahasiswa-unibo-dan...
# 17  https://suarajatimpost.com/pabrik-rokok-teranc...
# 18  https://suarajatimpost.com/gelar-festival-buah...
# 19  https://suarajatimpost.com/redam-inflasi-dan-s...
# 20  https://suarajatimpost.com/bangkitkan-semangat...
# 21  https://suarajatimpost.com/wilayah-3t-di-jatim...
# 22  https://suarajatimpost.com/rpp-turunan-uu-kese...
# 23  https://suarajatimpost.com/bale-branti-bumdes-...
# 24  https://suarajatimpost.com/harga-cabai-gula-me...
# 25  https://suarajatimpost.com/tekanan-inflasi-kot...
# 26  https://suarajatimpost.com/produk-umkm-berbaga...
# 27  https://suarajatimpost.com/dua-poktan-tak-dapa...
# 28  https://suarajatimpost.com/ojk-kediri-sambangi...
# 29  https://suarajatimpost.com/tak-dapat-dbhct-dua...
# 30  https://suarajatimpost.com/usaha-es-krim-bisni...
# 31  https://suarajatimpost.com/bi-malang-kondisi-e...
#
#                                             thumbnail  \
# 0   https://suarajatimpost.com/uploads/images/2023...
# 1   https://suarajatimpost.com/uploads/images/2023...
# 2   https://suarajatimpost.com/uploads/images/2023...
# 3   https://suarajatimpost.com/uploads/images/2023...
# 4   https://suarajatimpost.com/uploads/images/2023...
# 5   https://suarajatimpost.com/uploads/images/2023...
# 6   https://suarajatimpost.com/uploads/images/2023...
# 7   https://suarajatimpost.com/uploads/images/2023...
# 8   https://suarajatimpost.com/uploads/images/2023...
# 9   https://suarajatimpost.com/uploads/images/2023...
# 10  https://suarajatimpost.com/uploads/images/2023...
# 11  https://suarajatimpost.com/uploads/images/2023...
# 12  https://suarajatimpost.com/uploads/images/2023...
# 13  https://suarajatimpost.com/uploads/images/2023...
# 14  https://suarajatimpost.com/uploads/images/2023...
# 15  https://suarajatimpost.com/uploads/images/2023...
# 16  https://suarajatimpost.com/uploads/images/2023...
# 17  https://suarajatimpost.com/uploads/images/2023...
# 18  https://suarajatimpost.com/uploads/images/2023...
# 19  https://suarajatimpost.com/uploads/images/2023...
# 20  https://suarajatimpost.com/uploads/images/2023...
# 21  https://suarajatimpost.com/uploads/images/2023...
# 22  https://suarajatimpost.com/uploads/images/2023...
# 23  https://suarajatimpost.com/uploads/images/2023...
# 24  https://suarajatimpost.com/uploads/images/2023...
# 25  https://suarajatimpost.com/uploads/images/2023...
# 26  https://suarajatimpost.com/uploads/images/2023...
# 27  https://suarajatimpost.com/uploads/images/2023...
# 28  https://suarajatimpost.com/uploads/images/2023...
# 29  https://suarajatimpost.com/uploads/images/2023...
# 30  https://suarajatimpost.com/uploads/images/2023...
# 31  https://suarajatimpost.com/uploads/images/2023...
#
#                                               content               author  \
# 0   Kabupaten Bondowoso, SJP - Fakultas Hukum Univ...         Rizqi Ardian
# 1   Kabupaten Malang, SJP - Perusahaan rokok (PR) ...   Toski Dermaleksana
# 2   Kabupaten Tuban, SJP - Sebagai produsen padi t...                 Atmo
# 3   Kota Probolinggo, SJP - Guna stabilkan harga b...         Rizqi Ardian
# 4   Malang, SJP - Menghadapi acara One Mount Entre...          michel sima
# 5   Surabaya, SJP - Ekspedisi Rupiah Berdaulat (ER...       Jefri yulianto
# 6   Malang, SJP - Sorotan dan kritik terhadap upay...              Redaksi
# 7   Kota Madiun, SJP - Siapa bilang Badan Usaha Mi...  Antok Setiyo Wibowo
# 8   Kabupaten Malang, SJP - Harga komoditas cabai ...         Ashril Hafid
# 9   Kota Malang, SJP - Badan Pusat Statistik (BPS)...         Ashril Hafid
# 10  Kota Pasuruan, SJP - Pelaksanaan Musabaqah Til...    isbiantohariutomo
# 11  Kabupaten Mojokerto, SJP - Koordinator Penyulu...          Andy Yuwono
# 12  Kota Madiun, SJP - Otoritas Jasa Keuangan (OJK...  Antok Setiyo Wibowo
# 13  Kabupaten Mojokerto, SJP - Tak dapat Dana Bagi...          Andy Yuwono
# 14  Kabupaten Jombang, SJP Setelah mengetahui tent...       Tuhu Wijayanto
# 15  Kota Malang, SJP — Berdasarkan Survei Konsumen...         Ashril Hafid
# 16  Kabupaten Bondowoso, SJP - Fakultas Hukum Univ...         Rizqi Ardian
# 17  Kabupaten Malang, SJP - Perusahaan rokok (PR) ...   Toski Dermaleksana
# 18  Kabupaten Tuban, SJP - Sebagai produsen padi t...                 Atmo
# 19  Kota Probolinggo, SJP - Guna stabilkan harga b...         Rizqi Ardian
# 20  Malang, SJP - Menghadapi acara One Mount Entre...          michel sima
# 21  Surabaya, SJP - Ekspedisi Rupiah Berdaulat (ER...       Jefri yulianto
# 22  Malang, SJP - Sorotan dan kritik terhadap upay...              Redaksi
# 23  Kota Madiun, SJP - Siapa bilang Badan Usaha Mi...  Antok Setiyo Wibowo
# 24  Kabupaten Malang, SJP - Harga komoditas cabai ...         Ashril Hafid
# 25  Kota Malang, SJP - Badan Pusat Statistik (BPS)...         Ashril Hafid
# 26  Kota Pasuruan, SJP - Pelaksanaan Musabaqah Til...    isbiantohariutomo
# 27  Kabupaten Mojokerto, SJP - Koordinator Penyulu...          Andy Yuwono
# 28  Kota Madiun, SJP - Otoritas Jasa Keuangan (OJK...  Antok Setiyo Wibowo
# 29  Kabupaten Mojokerto, SJP - Tak dapat Dana Bagi...          Andy Yuwono
# 30  Kabupaten Jombang, SJP Setelah mengetahui tent...       Tuhu Wijayanto
# 31  Kota Malang, SJP — Berdasarkan Survei Konsumen...         Ashril Hafid
#
#            publish_date
# 0   10 Oct 2023 - 22:00
# 1   10 Oct 2023 - 16:00
# 2   09 Oct 2023 - 10:30
# 3   08 Oct 2023 - 19:30
# 4   08 Oct 2023 - 11:15
# 5   07 Oct 2023 - 06:45
# 6   06 Oct 2023 - 06:00
# 7   05 Oct 2023 - 11:15
# 8   03 Oct 2023 - 20:45
# 9   03 Oct 2023 - 19:15
# 10  03 Oct 2023 - 11:45
# 11  02 Oct 2023 - 22:00
# 12  02 Oct 2023 - 21:45
# 13  02 Oct 2023 - 19:45
# 14  02 Oct 2023 - 14:30
# 15  30 Sep 2023 - 20:15
# 16  10 Oct 2023 - 22:00
# 17  10 Oct 2023 - 16:00
# 18  09 Oct 2023 - 10:30
# 19  08 Oct 2023 - 19:30
# 20  08 Oct 2023 - 11:15
# 21  07 Oct 2023 - 06:45
# 22  06 Oct 2023 - 06:00
# 23  05 Oct 2023 - 11:15
# 24  03 Oct 2023 - 20:45
# 25  03 Oct 2023 - 19:15
# 26  03 Oct 2023 - 11:45
# 27  02 Oct 2023 - 22:00
# 28  02 Oct 2023 - 21:45
# 29  02 Oct 2023 - 19:45
# 30  02 Oct 2023 - 14:30
# 31  30 Sep 2023 - 20:15
